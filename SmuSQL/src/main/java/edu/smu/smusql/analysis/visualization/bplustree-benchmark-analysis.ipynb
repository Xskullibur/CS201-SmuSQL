# %%
import warnings

from benchmark_visualizer import BenchmarkVisualizer

visualizer = BenchmarkVisualizer([
    "results/bplusarray_nocache_results.csv",
    "results/bplusarray_withcache_results.csv",
    "results/bplushashmap_nocache_results.csv",
    "results/bplushashmap_withcache_results.csv"
])
# Out:
# Loaded data from 4 files:
# - Total rows: 3232
# - Engines: bplusarray, bplushashmap
# - Configurations: nocache, withcache
# - Query types: DELETE, EQUALS_SELECT, EQUALS_UPDATE, INSERT, RANGE_SELECT, RANGE_UPDATE, SIMPLE_SELECT, UPDATE

# %%
print("Execution Time Distribution Analysis")
visualizer.plot_execution_time_distribution()
# Out:
# Execution Time Distribution Analysis

# %% [markdown]
# - DELETE and single-point UPDATE operations are consistently fast across all data structures.
# - RANGE SELECT and RANGE UPDATE are more time-intensive, with RANGE UPDATE showing the highest computational demands, potentially favoring `bplusarray_withcache` for ordered operations.
# - INSERT operations are consistent across all implementations except for `bplushashmap_withcache`, which shows a significant increase in execution time.
# - SIMPLE SELECT show a larger variability across implementations with the cached implementations showing a slight advantage.

# %%
print("Query Time Trend Analysis")
visualizer.plot_query_time_trends()
# Out:
# Query Time Trend Analysis

# %% [markdown]
# ## Cache Impact
# - Cache implementations generally perform similarly to their "nocache" counterparts in most operations
# - In SIMPLE_SELECT operations, having cache appears to provide better performance for the array implementation
#
# ## Data Structure Comparison
# - Hashmap tends to have slightly higher execution times compared to bplusarray in most operations

# %%
print("Range vs Equals Operations Analysis")
visualizer.plot_range_vs_equals_comparison()
# Out:
# Range vs Equals Operations Analysis
# E:\.current\projects\CS201-proj-SkipList\SmuSQL\src\main\java\edu\smu\smusql\analysis\visualization\benchmark_visualizer.py:372: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(data=select_ops,
# E:\.current\projects\CS201-proj-SkipList\SmuSQL\src\main\java\edu\smu\smusql\analysis\visualization\benchmark_visualizer.py:380: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
# E:\.current\projects\CS201-proj-SkipList\SmuSQL\src\main\java\edu\smu\smusql\analysis\visualization\benchmark_visualizer.py:386: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(data=update_ops,
# E:\.current\projects\CS201-proj-SkipList\SmuSQL\src\main\java\edu\smu\smusql\analysis\visualization\benchmark_visualizer.py:394: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)

# %% [markdown]
# - RANGE operations are generally faster than EQUAL operations
# - `bplusarray` shows slightly better performance characteristics overall
# - Addition of cache doesn't significantly improve performance in most cases

# %%
print("Performance Comparison Dashboard")
visualizer.plot_performance_comparison()
# Out:
# Performance Comparison Dashboard
# E:\.current\projects\CS201-proj-SkipList\SmuSQL\src\main\java\edu\smu\smusql\analysis\visualization\benchmark_visualizer.py:254: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x='EngineType', y='HeapMemoryUsed',

# %% [markdown]
# - Overall based on execution time and memory usage, `bplusarray` with cache appears to be the best performing data structure

# %%
visualizer = BenchmarkVisualizer([
    "results/hashmap_default_results.csv",
    "results/skiphash_default_results.csv",
    "results/skipindexed_default_results.csv",
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File E:\.current\projects\CS201-proj-SkipList\SmuSQL\src\main\java\edu\smu\smusql\analysis\visualization\benchmark_visualizer.py:57, in BenchmarkVisualizer.__init__(self, csv_files)
#      56 if missing_columns:
# ---> 57     raise ValueError(
#      58         f"Missing required columns in {file}: {', '.join(missing_columns)}"
#      59     )
#      61 # Add engine and configuration information
#
# ValueError: Missing required columns in results/hashmap_default_results.csv: AverageExecutionTime, HeapMemoryUsed, HeapMemoryDelta
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 visualizer = BenchmarkVisualizer([
#       2     "results/hashmap_default_results.csv",
#       3     "results/skiphash_default_results.csv",
#       4     "results/skipindexed_default_results.csv",
#       5 ])
#
# File E:\.current\projects\CS201-proj-SkipList\SmuSQL\src\main\java\edu\smu\smusql\analysis\visualization\benchmark_visualizer.py:73, in BenchmarkVisualizer.__init__(self, csv_files)
#      71         raise ValueError(f"CSV file is empty: {file}")
#      72     except Exception as e:
# ---> 73         raise ValueError(f"Error processing {file}: {str(e)}")
#      75 # Combine all DataFrames
#      76 try:
#
# ValueError: Error processing results/hashmap_default_results.csv: Missing required columns in results/hashmap_default_results.csv: AverageExecutionTime, HeapMemoryUsed, HeapMemoryDelta
