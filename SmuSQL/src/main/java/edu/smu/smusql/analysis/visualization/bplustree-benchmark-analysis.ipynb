# %%
import warnings

from benchmark_visualizer import BenchmarkVisualizer

visualizer = BenchmarkVisualizer([
    "results/bplusarray_nocache_results.csv",
    "results/bplusarray_withcache_results.csv",
    "results/bplushashmap_nocache_results.csv",
    "results/bplushashmap_withcache_results.csv"
])
# Out:
# Loaded data from 4 files:
# - Total rows: 352
# - Engines: bplusarray_nocache, bplusarray_withcache, bplushashmap_nocache, bplushashmap_withcache
# - Query types: DELETE, EQUALS_SELECT, EQUALS_UPDATE, INSERT, RANGE_SELECT, RANGE_UPDATE, SIMPLE_SELECT, UPDATE

# %%
print("Execution Time Distribution Analysis")
visualizer.plot_execution_time_distribution()
# Out:
# Execution Time Distribution Analysis
#
# Summary Statistics by Query Type and Engine:
#                                       count   mean    std    min    max
# QueryType     EngineConfig
# DELETE        bplusarray_nocache         11  0.001  0.000  0.001  0.001
#               bplusarray_withcache       11  0.001  0.000  0.001  0.001
#               bplushashmap_nocache       11  0.001  0.000  0.001  0.001
#               bplushashmap_withcache     11  0.001  0.000  0.001  0.001
# EQUALS_SELECT bplusarray_nocache         11  0.040  0.022  0.001  0.070
#               bplusarray_withcache       11  0.042  0.019  0.020  0.070
#               bplushashmap_nocache       11  0.043  0.024  0.001  0.070
#               bplushashmap_withcache     11  0.053  0.018  0.030  0.080
# EQUALS_UPDATE bplusarray_nocache         11  0.118  0.072  0.020  0.220
#               bplusarray_withcache       11  0.122  0.067  0.040  0.220
#               bplushashmap_nocache       11  0.133  0.077  0.030  0.240
#               bplushashmap_withcache     11  0.149  0.074  0.060  0.260
# INSERT        bplusarray_nocache         11  0.041  0.019  0.020  0.070
#               bplusarray_withcache       11  0.043  0.018  0.020  0.070
#               bplushashmap_nocache       11  0.044  0.018  0.020  0.070
#               bplushashmap_withcache     11  0.051  0.012  0.040  0.070
# RANGE_SELECT  bplusarray_nocache         11  0.145  0.075  0.040  0.250
#               bplusarray_withcache       11  0.147  0.073  0.050  0.250
#               bplushashmap_nocache       11  0.154  0.078  0.040  0.260
#               bplushashmap_withcache     11  0.179  0.070  0.090  0.280
# RANGE_UPDATE  bplusarray_nocache         11  0.296  0.164  0.060  0.520
#               bplusarray_withcache       11  0.306  0.153  0.100  0.520
#               bplushashmap_nocache       11  0.339  0.182  0.070  0.580
#               bplushashmap_withcache     11  0.374  0.162  0.170  0.600
# SIMPLE_SELECT bplusarray_nocache         11  0.238  0.133  0.050  0.420
#               bplusarray_withcache       11  0.176  0.091  0.050  0.300
#               bplushashmap_nocache       11  0.278  0.151  0.060  0.480
#               bplushashmap_withcache     11  0.228  0.101  0.100  0.370
# UPDATE        bplusarray_nocache         11  0.001  0.000  0.001  0.001
#               bplusarray_withcache       11  0.001  0.000  0.001  0.001
#               bplushashmap_nocache       11  0.001  0.000  0.001  0.001
#               bplushashmap_withcache     11  0.001  0.000  0.001  0.001

# %% [markdown]
# - DELETE and single-point UPDATE operations are consistently fast across all data structures.
# - RANGE SELECT and RANGE UPDATE are more time-intensive, with RANGE UPDATE showing the highest computational demands, potentially favoring `bplusarray_withcache` for ordered operations.
# - INSERT operations are consistent across all implementations except for `bplushashmap_withcache`, which shows a significant increase in execution time.
# - SIMPLE SELECT show a larger variability across implementations with the cached implementations showing a slight advantage.

# %%
print("Query Time Trend Analysis")
visualizer.plot_query_time_trends()
# Out:
# Query Time Trend Analysis
#
# Performance Trend Summary Statistics:
#
# DELETE:
#                         mean  std   min   max
# EngineConfig
# bplusarray_nocache      0.00  0.0  0.00  0.00
# bplusarray_withcache    0.00  0.0  0.00  0.00
# bplushashmap_nocache    0.00  0.0  0.00  0.00
# bplushashmap_withcache  0.01  0.0  0.01  0.01
#
# EQUALS_SELECT:
#                          mean    std   min   max
# EngineConfig
# bplusarray_nocache      0.041  0.021  0.01  0.07
# bplusarray_withcache    0.042  0.019  0.02  0.07
# bplushashmap_nocache    0.044  0.022  0.01  0.07
# bplushashmap_withcache  0.053  0.018  0.03  0.08
#
# EQUALS_UPDATE:
#                          mean    std   min   max
# EngineConfig
# bplusarray_nocache      0.118  0.072  0.02  0.22
# bplusarray_withcache    0.122  0.067  0.04  0.22
# bplushashmap_nocache    0.133  0.077  0.03  0.24
# bplushashmap_withcache  0.149  0.074  0.06  0.26
#
# INSERT:
#                          mean    std   min   max
# EngineConfig
# bplusarray_nocache      0.041  0.019  0.02  0.07
# bplusarray_withcache    0.043  0.018  0.02  0.07
# bplushashmap_nocache    0.044  0.018  0.02  0.07
# bplushashmap_withcache  0.051  0.012  0.04  0.07
#
# RANGE_SELECT:
#                          mean    std   min   max
# EngineConfig
# bplusarray_nocache      0.145  0.075  0.04  0.25
# bplusarray_withcache    0.147  0.073  0.05  0.25
# bplushashmap_nocache    0.154  0.078  0.04  0.26
# bplushashmap_withcache  0.179  0.070  0.09  0.28
#
# RANGE_UPDATE:
#                          mean    std   min   max
# EngineConfig
# bplusarray_nocache      0.296  0.164  0.06  0.52
# bplusarray_withcache    0.306  0.153  0.10  0.52
# bplushashmap_nocache    0.339  0.182  0.07  0.58
# bplushashmap_withcache  0.374  0.162  0.17  0.60
#
# SIMPLE_SELECT:
#                          mean    std   min   max
# EngineConfig
# bplusarray_nocache      0.238  0.133  0.05  0.42
# bplusarray_withcache    0.176  0.091  0.05  0.30
# bplushashmap_nocache    0.278  0.151  0.06  0.48
# bplushashmap_withcache  0.228  0.101  0.10  0.37
#
# UPDATE:
#                          mean    std   min   max
# EngineConfig
# bplusarray_nocache      0.005  0.005  0.00  0.01
# bplusarray_withcache    0.010  0.000  0.01  0.01
# bplushashmap_nocache    0.009  0.003  0.00  0.01
# bplushashmap_withcache  0.010  0.000  0.01  0.01

# %% [markdown]
# ## Cache Impact
# - Cache implementations generally perform similarly to their "nocache" counterparts in most operations
# - In SIMPLE_SELECT operations, having cache appears to provide better performance for the array implementation
#
# ## Data Structure Comparison
# - Hashmap tends to have slightly higher execution times compared to bplusarray in most operations

# %%
print("Range vs Equals Operations Analysis")
visualizer.plot_range_vs_equals_comparison()
# Out:
# Range vs Equals Operations Analysis
# E:\.current\projects\CS201-proj-SkipList\SmuSQL\src\main\java\edu\smu\smusql\analysis\visualization\benchmark_visualizer.py:256: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
# E:\.current\projects\CS201-proj-SkipList\SmuSQL\src\main\java\edu\smu\smusql\analysis\visualization\benchmark_visualizer.py:264: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)

# %% [markdown]
# - RANGE operations are generally faster than EQUAL operations
# - `bplusarray` shows slightly better performance characteristics overall
# - Addition of cache doesn't significantly improve performance in most cases

# %%
print("Performance Comparison Dashboard")
visualizer.plot_performance_comparison()
# Out:
# Performance Comparison Dashboard

# %% [markdown]
# - Overall based on execution time and memory usage, `bplusarray` with cache appears to be the best performing data structure

# %%
visualizer = BenchmarkVisualizer([
    "results/hashmap_default_results.csv",
    "results/skiphash_default_results.csv",
    "results/skipindexed_default_results.csv",
])
# Out:
# Loaded data from 3 files:
# - Total rows: 264
# - Engines: hashmap_default, skiphash_default, skipindexed_default
# - Query types: DELETE, EQUALS_SELECT, EQUALS_UPDATE, INSERT, RANGE_SELECT, RANGE_UPDATE, SIMPLE_SELECT, UPDATE
