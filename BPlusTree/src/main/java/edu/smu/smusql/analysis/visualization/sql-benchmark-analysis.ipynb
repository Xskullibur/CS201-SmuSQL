# %%
from benchmark_visualizer import BenchmarkVisualizer
import warnings
warnings.filterwarnings('ignore')

visualizer = BenchmarkVisualizer([
    'results/bplus_nocache_results.csv',
    'results/bplus_withcache_results.csv'
])

# %%
print("Summary Statistics for All Engines")
visualizer.show_summary_statistics()
# Out:
# Summary Statistics for All Engines
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="4" halign="left">AverageExecutionTime</th>
#       <th>SuccessRate</th>
#       <th>HeapMemoryUsed</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>max</th>
#       <th>mean</th>
#       <th>mean</th>
#     </tr>
#     <tr>
#       <th>EngineType</th>
#       <th>QueryType</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="8" valign="top">bplus_nocache</th>
#       <th>DELETE</th>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>100.0</td>
#       <td>2.337455e+08</td>
#     </tr>
#     <tr>
#       <th>EQUALS_SELECT</th>
#       <td>0.04</td>
# ...

# %%
print("Execution Time Distribution Analysis")
visualizer.plot_execution_time_distribution()
# Out:
# Execution Time Distribution Analysis

# %% [markdown]
# # Memory Usage Analysis
# This measures memory usage over time for each operation without forcing garbage collection. It shows the memory impact of each operation and how memory usage changes over time. But it does not reflect true long-term memory consumption, as natural garbage collection events (appearing as negative spikes) are not tracked.

# %%
print("Memory Usage Analysis")
visualizer.plot_memory_usage_over_time()
# Out:
# Memory Usage Analysis

# %%
print("Query Time Trend Analysis")
visualizer.plot_query_time_trends()
# Out:
# Query Time Trend Analysis

# %%
print("Range vs Equals Operations Analysis")
visualizer.plot_range_vs_equals_comparison()
# Out:
# Range vs Equals Operations Analysis

# %%
print("Performance Comparison Dashboard")
visualizer.plot_performance_comparison()
# Out:
# Performance Comparison Dashboard
